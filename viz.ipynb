# %%
import pandas as pd
quakes = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/earthquakes-23k.csv')

import plotly.graph_objects as go
fig = go.Figure(go.Densitymapbox(lat=joined.Latitude, lon=joined.Longitude, z=joined.Temp,
                                 radius=10))
fig.update_layout(mapbox_style="stamen-terrain", mapbox_center_lon=180)
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()
# Out:
# Executing shutdown due to inactivity...
# 2023-02-04 14:20:30,576 - INFO     - Executing shutdown due to inactivity...
# Executing shutdown...
# 2023-02-04 14:20:30,758 - INFO     - Executing shutdown...
# /Users/vedant1/opt/anaconda3/lib/python3.9/site-packages/dtale/app.py:422: UserWarning:
#
# The 'environ['werkzeug.server.shutdown']' function is deprecated and will be removed in Werkzeug 2.1.

# %%
import dtale

temp = pd.read_csv('/Users/vedant1/Desktop/College/Classes/Fall_2021/DS2500/HW2/temp_1986.csv', header=None).rename({0:'station_id', 2:'Month', 3:'Day', 4:'Temp'}, axis=1)
stations = pd.read_csv('/Users/vedant1/Desktop/College/Classes/Fall_2021/DS2500/HW2/stations.csv', header=None).rename({0:'station_id', 2:'Latitude', 3:'Longitude'}, axis=1)
joined = temp.join(stations, on='station_id', how='inner', lsuffix='temp', rsuffix='stations')[['station_id', 'Latitude', 'Longitude', 'Month', 'Day', 'Temp']]
# dtale.show(temp).open_browser()
# dtale.show(stations).open_browser()
dtale.show(joined).open_browser()

# %%
import json
import geopandas as gpd
colleges = gpd.read_file('/Users/vedant1/Desktop/College/Classes/Fall_2021/DS2500/Lab #9/colleges.geojson')
# colleges = json.loads('/Users/vedant1/Desktop/College/Classes/Fall_2021/DS2500/Lab #9/colleges.geojson')
colleges
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/g1/_6qfg71x03x35bdydk63jnfm0000gp/T/ipykernel_40294/1326648533.py in <module>
#       1 import json
# ----> 2 import geopandas as gpd
#       3 colleges = gpd.read_file('/Users/vedant1/Desktop/College/Classes/Fall_2021/DS2500/Lab #9/colleges.geojson')
#       4 # colleges = json.loads('/Users/vedant1/Desktop/College/Classes/Fall_2021/DS2500/Lab #9/colleges.geojson')
#       5 colleges
#
# ModuleNotFoundError: No module named 'geopandas'

# %%
conda install geopandas
# Out:
# Retrieving notices: ...working... done
# ...
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/vedant1/opt/anaconda3
#
#   added / updated specs:
#     - geopandas
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     cairo-1.16.0               |       h691a603_2         935 KB
#     click-plugins-1.1.1        |     pyhd3eb1b0_0          10 KB
#     cligj-0.7.2                |   py39hecd8cb5_0          13 KB
#     fiona-1.8.22               |   py39h07fba90_0         733 KB
#     fontconfig-2.14.1          |       h1659381_0         240 KB
#     freexl-1.0.6               |       h9ed2024_0          38 KB
# ...
